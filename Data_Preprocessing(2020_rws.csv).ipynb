# %%
# Importing all important Libraries

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib as plt

from IPython import display

pd.set_option('display.max_columns',None)

pd.set_option('display.max_rows',None)

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Collection :

# %%
# df = pd.read_csv('2020_rws.csv')
# df.head()
import pandas as pd

try:
    df = pd.read_csv('2020_rws.csv', encoding='latin1')  # or encoding='iso-8859-1'
    print(df.head())
except UnicodeDecodeError:
    print("Error: Unable to read the file with the specified encoding.")
# Out:
#    Response ID  What year were you born? What is your gender?  \
# 0            1                      1972               Female
# 1            2                      1972                 Male
# 2            3                      1982                 Male
# 3            4                      1987               Female
# 4            5                      1991                 Male
#
#   Which of the following best describes your industry?  \
# 0                                      Manufacturing
# 1                                    Wholesale Trade
# 2         Electricity, Gas, Water and Waste Services
# 3    Professional, Scientific and Technical Services
# 4                  Transport, Postal and Warehousing
#
#   Which of the following best describes your industry? (Detailed)  \
# 0                         Food Product Manufacturing
# 1                            Other Goods Wholesaling
# 2                                         Gas Supply
# ...

# %%
df.head()
# Out:
#    Response ID  What year were you born? What is your gender?  \
# 0            1                      1972               Female
# 1            2                      1972                 Male
# 2            3                      1982                 Male
# 3            4                      1987               Female
# 4            5                      1991                 Male
#
#   Which of the following best describes your industry?  \
# 0                                      Manufacturing
# 1                                    Wholesale Trade
# 2         Electricity, Gas, Water and Waste Services
# 3    Professional, Scientific and Technical Services
# 4                  Transport, Postal and Warehousing
#
#   Which of the following best describes your industry? (Detailed)  \
# 0                         Food Product Manufacturing
# 1                            Other Goods Wholesaling
# 2                                         Gas Supply
# ...

# %% [markdown]
# ## Data Preprocessing :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1507 entries, 0 to 1506
# Data columns (total 73 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                              --------------  -----
# ...

# %%
df.describe()
# Out:
#        Response ID  What year were you born?  \
# count  1507.000000               1507.000000
# mean    754.000000               1974.791639
# std     435.177741                 11.875588
# min       1.000000               1900.000000
# 25%     377.500000               1965.000000
# 50%     754.000000               1975.000000
# 75%    1130.500000               1985.000000
# max    1507.000000               2001.000000
#
#        On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting  \
# count                                        1507.000000
# mean                                            1.795786
# std                                             1.379599
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.500000
# ...

# %%
df.nunique()
# Out:
# Response ID                                                                                                                                                                                                                                                                                                                                                                                           1507
# What year were you born?                                                                                                                                                                                                                                                                                                                                                                                50
# ...

# %%
df.shape
# Out:
# (1507, 73)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1507, step=1),
#  Index(['Response ID', 'What year were you born?', 'What is your gender?',
#         'Which of the following best describes your industry?',
#         'Which of the following best describes your industry? (Detailed)',
#         'Which of the following best describes your current occupation?',
#         'Which of the following best describes your current occupation? (Detailed)',
#         'How many people are currently employed by your organisation?',
#         'Do you manage people as part of your current occupation?',
#         'Which of the following best describes your household?',
#         'How long have you been in your current job?', 'Metro / Regional',
#         'Thinking about your current job, how much of your time did you spend remote working last year?',
#         'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely',
# ...

# %%
df.columns
# Out:
# Index(['Response ID', 'What year were you born?', 'What is your gender?',
#        'Which of the following best describes your industry?',
#        'Which of the following best describes your industry? (Detailed)',
#        'Which of the following best describes your current occupation?',
#        'Which of the following best describes your current occupation? (Detailed)',
#        'How many people are currently employed by your organisation?',
#        'Do you manage people as part of your current occupation?',
#        'Which of the following best describes your household?',
#        'How long have you been in your current job?', 'Metro / Regional',
#        'Thinking about your current job, how much of your time did you spend remote working last year?',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1507, step=1)

# %%
df.dtypes
# Out:
# Response ID                                                                                                                                                                                                                                                                                                                                                                                             int64
# What year were you born?                                                                                                                                                                                                                                                                                                                                                                                int64
# ...

# %%
df.isna().sum()
# Out:
# Response ID                                                                                                                                                                                                                                                                                                                                                                                             0
# What year were you born?                                                                                                                                                                                                                                                                                                                                                                                0
# ...

# %%
df.fillna(99999,inplace = True)

# %%
df.isna().sum()
# Out:
# Response ID                                                                                                                                                                                                                                                                                                                                                                                           0
# What year were you born?                                                                                                                                                                                                                                                                                                                                                                              0
# ...

# %% [markdown]
# ## Data Visualization :

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.distplot(df['What year were you born?'])
# Out:
# <Axes: xlabel='What year were you born?', ylabel='Density'>

# %% [markdown]
# ## Compairing Numerical Columns with Categorical columns :

# %%
df.select_dtypes(include = 'object').head()
# Out:
#   What is your gender? Which of the following best describes your industry?  \
# 0               Female                                      Manufacturing
# 1                 Male                                    Wholesale Trade
# 2                 Male         Electricity, Gas, Water and Waste Services
# 3               Female    Professional, Scientific and Technical Services
# 4                 Male                  Transport, Postal and Warehousing
#
#   Which of the following best describes your industry? (Detailed)  \
# 0                         Food Product Manufacturing
# 1                            Other Goods Wholesaling
# 2                                         Gas Supply
# 3    Professional, Scientific and Technical Services
# 4                                    Other Transport
#
#   Which of the following best describes your current occupation?  \
# 0                       Clerical and administrative
# 1                                           Managers
# ...

# %%
df.select_dtypes(exclude = 'object').head()
# Out:
#    Response ID  What year were you born?  \
# 0            1                      1972
# 1            2                      1972
# 2            3                      1982
# 3            4                      1987
# 4            5                      1991
#
#    On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting  \
# 0                                                2.0
# 1                                                2.0
# 2                                                6.0
# 3                                                1.0
# 4                                                1.0
#
#    On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working  \
# 0                                                8.0
# 1                                                7.0
# 2                                                1.0
# ...

# %% [markdown]
# ### using groupby :

# %%
df.groupby('On a day when you do remote work, how many hours would you spend doing the following activities? - Caring and domestic responsibilities').first().head()
# Out:
#                                                     Response ID  \
# On a day when you do remote work, how many hour...
# 0.00                                                         27
# 0.05                                                       1130
# 0.20                                                        844
# 0.25                                                        634
# 0.40                                                        678
#
#                                                     What year were you born?  \
# On a day when you do remote work, how many hour...
# 0.00                                                                    1962
# 0.05                                                                    1977
# 0.20                                                                    1986
# 0.25                                                                    1983
# 0.40                                                                    1972
#
# ...

# %% [markdown]
# ## compairing two features :

# %%
pd.crosstab(df['What is your gender?'],df['Metro / Regional'])
# Out:
# Metro / Regional      Metro  Regional
# What is your gender?
# Female                  513       145
# Male                    708       139
# Rather not say            2         0

# %% [markdown]
# ## Handling Outliers :

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Response ID', 'What year were you born?', 'What is your gender?',
#        'Which of the following best describes your industry?',
#        'Which of the following best describes your industry? (Detailed)',
#        'Which of the following best describes your current occupation?',
#        'Which of the following best describes your current occupation? (Detailed)',
#        'How many people are currently employed by your organisation?',
#        'Do you manage people as part of your current occupation?',
#        'Which of the following best describes your household?',
#        'How long have you been in your current job?', 'Metro / Regional',
#        'Thinking about your current job, how much of your time did you spend remote working last year?',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely',
# ...

# %%
sns.boxplot(df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"])
# Out:
# <Axes: >

# %%
q1 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"].quantile(0.25)
q2 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"].quantile(0.50)
q3 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"].quantile(0.75)

IQR = q3 - q1
med = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"].median()

upper_tail = q3 + 1.5 * IQR
lower_tail = q1 - 1.5* IQR


print(q1)
print(q2)
print(q3)
print(med)

print(upper_tail)
print(lower_tail)
# Out:
# 1.0
# 1.5
# 2.0
# 1.5
# 3.5
# -0.5

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"]>upper_tail]
# Out:
# 2        6.0
# 31       4.0
# 42       4.0
# 84       6.0
# 107      5.0
# 132      4.0
# 149      5.0
# 153     10.0
# 156      4.0
# 163      5.0
# 177      5.0
# 222      4.0
# 228      4.0
# 273      4.5
# 280      4.0
# 288      5.0
# 300      4.0
# 342      4.0
# 360      4.0
# 381      4.5
# 400      5.0
# 442      4.0
# 459      4.0
# 507      5.0
# 517      4.0
# 522      5.0
# 542      4.0
# 544      4.5
# 568      4.0
# 608      4.0
# 623      4.0
# 625      4.0
# 645     10.0
# 666      4.0
# 669      7.0
# 676      4.0
# 680      4.0
# 685      4.0
# 696      6.0
# 700      5.0
# 706      4.0
# 722      4.0
# 749      4.0
# 765      4.0
# 786      5.0
# 805      6.0
# 818      4.0
# 828      5.0
# 831     10.0
# 834      4.0
# 859      4.0
# 892      4.0
# 896      6.0
# 922      4.0
# 962      4.0
# 965      4.0
# 992      5.0
# 997      5.0
# 1000    12.0
# 1010     6.0
# 1017     4.0
# 1031     4.0
# 1046     4.0
# 1064     4.0
# 1065     4.0
# 1103     4.5
# ...

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"]>upper_tail]=upper_tail

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"]>upper_tail]
# Out:
# Series([], Name: On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting, dtype: float64)

# %%
sns.boxplot(df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"])
# Out:
# <Axes: >

# %%
q1 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].quantile(0.25)
q2 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].quantile(0.50)
q3 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].quantile(0.75)

IQR = q3 - q1
med = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].median()

upper_tail = q3 + 1.5* IQR
lower_tail = q1 - 1.5* IQR


print(q1)
print(q2)
print(q3)
print(med)

print(upper_tail)
print(lower_tail)
# Out:
# 7.0
# 8.0
# 8.0
# 8.0
# 9.5
# 5.5

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"]>upper_tail]
# Out:
# 11      10.0
# 13      12.0
# 17      10.0
# 24      10.0
# 25      10.0
# 36      10.0
# 37      12.0
# 40      10.0
# 54      10.0
# 79      10.0
# 81      10.0
# 85      10.0
# 86      14.0
# 123     10.0
# 124     10.0
# 153     10.0
# 214     10.0
# 238     10.0
# 243     10.0
# 270     11.0
# 311     11.0
# 313     10.0
# 316     10.0
# 358     10.0
# 361     10.0
# 362     10.0
# 368     11.0
# 379     10.0
# 407     10.0
# 429     10.0
# 434     10.0
# 444     10.0
# 451     10.0
# 456     14.0
# 472     11.0
# 478     12.0
# 482     10.0
# 508     10.0
# 517     10.0
# 521     10.0
# 531     10.0
# 542     12.0
# 554     10.0
# 569     10.0
# 576     10.0
# 581     10.0
# 585     10.0
# 593     10.0
# 610     12.0
# 642     12.0
# 645     10.0
# 650     10.0
# 653     10.0
# 654     10.0
# 666     11.0
# 667     10.0
# 692     11.0
# 718     10.0
# 725     10.0
# 738     10.0
# 746     10.0
# 756     10.0
# 763     10.0
# 806     10.0
# 815     10.0
# 828     10.0
# ...

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"]>upper_tail]=upper_tail

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"]>upper_tail]
# Out:
# Series([], Name: On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working, dtype: float64)

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"]<lower_tail]

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"]<lower_tail]=lower_tail

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"]<lower_tail]
# Out:
# Series([], Name: On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working, dtype: float64)

# %%
sns.boxplot(df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"])
# Out:
# <Axes: >

# %%
q1 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"].quantile(0.25)
q2 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"].quantile(0.50)
q3 = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"].quantile(0.75)

IQR = q3 - q1
med = df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"].median()

upper_tail = q3 + 1.5 * IQR
lower_tail = q1 - 1.5* IQR


print(q1)
print(q2)
print(q3)
print(med)

print(upper_tail)
print(lower_tail)
# Out:
# 2.0
# 3.0
# 5.0
# 3.0
# 9.5
# -2.5

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"]>upper_tail]
# Out:
# 4       13.0
# 8       12.0
# 23      10.0
# 25      10.0
# 43      11.0
# 50      11.0
# 53      17.5
# 54      11.0
# 63      18.0
# 66      10.0
# 82      15.0
# 102     18.0
# 130     13.0
# 193     10.0
# 219     11.0
# 225     14.0
# 226     12.0
# 236     12.0
# 244     12.5
# 250     10.0
# 254     11.0
# 255     10.0
# 262     10.0
# 267     10.0
# 282     12.0
# 320     12.0
# 341     14.0
# 351     20.0
# 352     13.0
# 358     10.0
# 367     10.0
# 373     14.0
# 378     10.0
# 383     10.0
# 410     12.0
# 422     14.0
# 434     14.0
# 468     13.5
# 539     10.0
# 571     10.0
# 582     10.0
# 583     11.0
# 587     16.0
# 588     12.0
# 603     12.0
# 614     11.0
# 625     11.0
# 628     13.0
# 632     12.5
# 650     10.0
# 653     11.0
# 657     13.0
# 664     10.0
# 683     11.0
# 705     12.0
# 732     11.0
# 807     14.0
# 855     11.0
# 858     13.0
# 859     12.0
# 864     15.0
# 872     12.0
# 883     10.0
# 894     12.0
# 898     14.0
# 911     10.0
# ...

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"]>upper_tail]=upper_tail

# %%
df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"].loc[df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"]>upper_tail]
# Out:
# Series([], Name: On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time, dtype: float64)

# %%
sns.boxplot(df["On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time"])
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Response ID  What year were you born? What is your gender?  \
# 0            1                      1972               Female
# 1            2                      1972                 Male
# 2            3                      1982                 Male
# 3            4                      1987               Female
# 4            5                      1991                 Male
#
#   Which of the following best describes your industry?  \
# 0                                      Manufacturing
# 1                                    Wholesale Trade
# 2         Electricity, Gas, Water and Waste Services
# 3    Professional, Scientific and Technical Services
# 4                  Transport, Postal and Warehousing
#
#   Which of the following best describes your industry? (Detailed)  \
# 0                         Food Product Manufacturing
# 1                            Other Goods Wholesaling
# 2                                         Gas Supply
# ...

# %%
df11 = df.to_csv('RWS.csv')
df11
